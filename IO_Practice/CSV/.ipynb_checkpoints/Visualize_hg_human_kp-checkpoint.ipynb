# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_loss = pd.read_csv('loss_log.csv')
df_accur = pd.read_csv('accur_log.csv')

# %% [markdown]
# # Loss

# %%
print(len(df_loss))
print(len(df_accur))
df_loss.head()
# Out:
# 1461
# 146
#    iter_count      loss
# 0         100  0.718964
# 1         200  0.249534
# 2         300  0.144453
# 3         400  0.121753
# 4         500  0.104853

# %%
df_accur.head()
# Out:
#    Iter  avg_accur      head      neck     r_hip  l_anckle   l_wrist  \
# 0  1000   0.901580  0.905395  0.934279  0.908224  0.879879  0.867614
# 1  2000   0.915911  0.933463  0.948545  0.919626  0.910800  0.882393
# 2  3000   0.918633  0.937057  0.952239  0.923136  0.903555  0.890906
# 3  4000   0.920900  0.942458  0.959431  0.924423  0.910981  0.880056
# 4  5000   0.916985  0.942261  0.953580  0.910400  0.919458  0.883984
#
#      l_knee  l_shoulder     l_hip    r_knee  r_shoulder    pelvis   l_elbow  \
# 0  0.889867    0.917462  0.911926  0.892653    0.920174  0.912372  0.891451
# 1  0.914754    0.929868  0.920241  0.911427    0.927027  0.927564  0.901857
# 2  0.917896    0.935254  0.921764  0.914816    0.928209  0.931138  0.914125
# 3  0.914909    0.938467  0.929872  0.920314    0.933950  0.935511  0.905983
# 4  0.910911    0.928187  0.907613  0.913415    0.931456  0.921254  0.908312
#
#    r_anckle   r_elbow    thorax   r_wrist  MA
# 0  0.889320  0.890335  0.940453  0.873869 NaN
# 1  0.902301  0.896295  0.948897  0.879528 NaN
# 2  0.901480  0.895186  0.952229  0.879133 NaN
# 3  0.911737  0.897320  0.958989  0.870000 NaN
# 4  0.907518  0.905358  0.952191  0.875871 NaN

# %%
plt.plot(df_loss.iter_count.iloc[:-1], df_loss.loss[:-1])
plt.title("loss vs. iter_count 0 - 14000")
plt.xlabel('iter_count')
plt.ylabel('CE loss')
# Out:
# Text(0,0.5,'CE loss')

# %%
plt.plot(df_loss.iter_count.iloc[20:-1], df_loss.loss[20:-1])
plt.title("loss vs. iter_count 0 - 14000")
plt.xlabel('iter_count')
plt.ylabel('CE loss')
# Out:
# Text(0,0.5,'CE loss')

# %%
# moving average
win_size = 30
df_loss['MA'] = df_loss.loss.rolling(window=win_size).mean()

plt.plot(df_loss.iter_count.iloc[200:-win_size+1], df_loss.MA[200:-win_size+1])
plt.title("loss vs. iter_count ")
plt.xlabel('iter_count')
plt.ylabel('CE loss')
# Out:
# Text(0,0.5,'CE loss')

# %%
plt.plot(df_loss.iter_count.iloc[800:-win_size+1], df_loss.MA[800:-win_size+1])
plt.title("loss vs. iter_count ")
plt.xlabel('iter_count')
plt.ylabel('CE loss')
# Out:
# Text(0,0.5,'CE loss')

# %% [markdown]
# # Accuracy

# %%
plt.plot(df_accur.Iter, df_accur.avg_accur)
plt.title("Avg Accuracy vs. iter_count 0 - 14000")
plt.xlabel('iter_count')
plt.ylabel('Accuracdy')
# Out:
# Text(0,0.5,'Accuracdy')

# %%
# moving avg
win_size = 10
df_accur['MA'] = df_accur.avg_accur.rolling(window=win_size).mean()

plt.plot(df_accur.Iter.iloc[win_size-1:-win_size+1], df_accur.MA[win_size-1:-win_size+1])
plt.title("Avg Accuracy vs. iter_count 0 - 14000")
plt.xlabel('iter_count')
plt.ylabel('Accuracdy - Moving Avg (window=5)')
# Out:
# Text(0,0.5,'Accuracdy - Moving Avg (window=5)')

# %% [markdown]
# ### Side note:
# Structure info: hg model: 4 stack, 4 down-step each HG module, non-modified version, non-tiny.
# optimizer: RMSprop
# training params: init_lr: 2.5e-4, decay=.979, batch_size = 16, epoch = 200, epoch_size = 1000
